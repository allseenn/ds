# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4], dtype=str)
print(a)
# Out:
# ['1' '2' '3' '4']

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# '2'

# %%
a[-1]
# Out:
# '4'

# %%
a[1:-1]
# Out:
# array(['2', '3'], dtype='<U1')

# %% [markdown]
# ## Узнать размерность массива ndim

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (4,)

# %%
A = np.array([[1,2,3,1],
             [4,5,6,4],
             [7,8,9,7]])

# %%
A.ndim, A.shape
# Out:
# (2, (3, 4))

# %%
A.size
# Out:
# 12

# %%
A[0,0]
# Out:
# 1

# %%
A[0][0]
# Out:
# 1

# %%
A[-1,-2]
# Out:
# 9

# %%
B = A[1:,:3]
B
# Out:
# array([[4, 5, 6],
#        [7, 8, 9]])

# %%
B[0,0] = -4
A
# Out:
# array([[ 1,  2,  3,  1],
#        [-4,  5,  6,  4],
#        [ 7,  8,  9,  7]])
